# %% [markdown]
# <a href="https://colab.research.google.com/github/eher78/UCARE_Emotional_Generated_Art/blob/main/Project_Hephaestus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link to Helpful Website that helped me get the start of this: https://towardsdatascience.com/generating-modern-arts-using-generative-adversarial-network-gan-on-spell-39f67f83c7b4

# %% [markdown]
# **Lets start by creating some code to resize our images. **

# %%
import os
import numpy as np
from PIL import Image

# %% [markdown]
# We are then resizing the image size and image channel (color means 3 channels RGB)

# %%
image_size = 128
image_channels = 3
image_datafiles = 'artworks/'

image_path = image_datafiles

training_data = []

for filename in os.listdir(image_path):
  path = os.path.join(image_path, filename)
  image = Image.open(path).resize((image_size, image_size), Image.ANTIALIAS)
  training_data.append(np.asarray(image))

training_data = np.reshape(training_data, (-1, image_size, image_size, image_channels))
training_data = training_data / 127.5 - 1

np.save('artwork_data.npy', training_data)
print('Artwork Data uploaded...')
# Out:
# Artwork Data uploaded...

# %%
# TO VERIFY:
np.load('artwork_data.npy')
# Out:
# array([[[[-0.23137255, -0.16862745, -0.09803922],
#          [-0.2627451 , -0.18431373, -0.10588235],
#          [-0.28627451, -0.2       , -0.12156863],
#          ...,
#          [-0.14509804, -0.16078431, -0.38039216],
#          [-0.10588235, -0.20784314, -0.39607843],
#          [-0.08235294, -0.24705882, -0.41176471]],
#
#         [[-0.34117647, -0.2627451 , -0.16862745],
#          [-0.34901961, -0.25490196, -0.16862745],
#          [-0.35686275, -0.23921569, -0.14509804],
#          ...,
#          [-0.2627451 , -0.23921569, -0.40392157],
#          [-0.22352941, -0.23921569, -0.41176471],
#          [-0.21568627, -0.24705882, -0.45882353]],
#
#         [[-0.39607843, -0.25490196, -0.09803922],
#          [-0.35686275, -0.22352941, -0.09803922],
#          [-0.36470588, -0.22352941, -0.09803922],
#          ...,
#          [-0.20784314, -0.14509804, -0.38039216],
#          [-0.30980392, -0.31764706, -0.49019608],
#          [-0.37254902, -0.38823529, -0.55294118]],
#
#         ...,
#
#         [[ 0.17647059, -0.38823529, -0.6       ],
#          [ 0.16078431, -0.41960784, -0.63137255],
#          [ 0.16078431, -0.45882353, -0.67843137],
#          ...,
#          [ 0.02745098,  0.09019608, -0.36470588],
#          [ 0.02745098,  0.09019608, -0.3254902 ],
#          [ 0.04313725,  0.08235294, -0.36470588]],
#
#         [[ 0.18431373, -0.36470588, -0.54509804],
#          [ 0.16862745, -0.41960784, -0.59215686],
#          [ 0.10588235, -0.42745098, -0.64705882],
#          ...,
#          [ 0.05882353,  0.11372549, -0.36470588],
#          [ 0.01176471,  0.0745098 , -0.35686275],
#          [-0.01176471,  0.04313725, -0.36470588]],
#
#         [[ 0.0745098 , -0.23921569, -0.43529412],
#          [ 0.11372549, -0.29411765, -0.52156863],
#          [ 0.15294118, -0.28627451, -0.59215686],
#          ...,
#          [-0.05882353, -0.01960784, -0.33333333],
#          [-0.12156863, -0.09803922, -0.42745098],
#          [-0.14509804, -0.12941176, -0.45882353]]],
#
#
#        [[[-0.49803922, -0.56862745, -0.63921569],
#          [-0.37254902, -0.48235294, -0.60784314],
#          [-0.49803922, -0.49803922, -0.56078431],
#          ...,
#          [ 0.0745098 ,  0.02745098, -0.09803922],
#          [ 0.02745098, -0.01176471, -0.12156863],
#          [-0.02745098, -0.09803922, -0.25490196]],
#
#         [[-0.4745098 , -0.55294118, -0.64705882],
#          [-0.31764706, -0.41960784, -0.59215686],
#          [-0.62352941, -0.56862745, -0.56862745],
#          ...,
#          [-0.43529412, -0.42745098, -0.4745098 ],
#          [-0.43529412, -0.43529412, -0.50588235],
#          [-0.45098039, -0.50588235, -0.62352941]],
#
#         [[-0.43529412, -0.52156863, -0.63137255],
#          [-0.11372549, -0.24705882, -0.50588235],
#          [-0.41176471, -0.45098039, -0.60784314],
#          ...,
#          [ 0.19215686,  0.0745098 , -0.12941176],
#          [ 0.17647059,  0.05882353, -0.15294118],
#          [ 0.10588235, -0.02745098, -0.27058824]],
#
#         ...,
#
#         [[ 0.67058824,  0.36470588, -0.05882353],
#          [ 0.67843137,  0.58431373,  0.45882353],
#          [ 0.78039216,  0.7254902 ,  0.65490196],
#          ...,
#          [ 0.14509804, -0.01176471, -0.23137255],
#          [ 0.12941176, -0.01960784, -0.23137255],
#          [ 0.17647059,  0.02745098, -0.16078431]],
#
#         [[ 0.70196078,  0.36470588, -0.04313725],
#          [ 0.52156863,  0.3254902 ,  0.10588235],
#          [ 0.7254902 ,  0.69411765,  0.63921569],
#          ...,
#          [ 0.05098039, -0.0745098 , -0.25490196],
#          [ 0.14509804,  0.03529412, -0.14509804],
#          [ 0.0745098 , -0.08235294, -0.28627451]],
#
#         [[ 0.78039216,  0.43529412, -0.03529412],
#          [ 0.67843137,  0.33333333, -0.10588235],
#          [ 0.61568627,  0.39607843,  0.09803922],
#          ...,
#          [-0.16862745, -0.30980392, -0.48235294],
#          [-0.36470588, -0.52156863, -0.69411765],
#          [-0.6       , -0.76470588, -0.92941176]]],
#
#
#        [[[-0.58431373, -0.52941176, -0.5372549 ],
#          [-0.45098039, -0.38039216, -0.46666667],
#          [-0.56862745, -0.44313725, -0.41176471],
#          ...,
#          [-0.97647059, -1.        , -1.        ],
#          [-0.96862745, -0.9372549 , -0.78039216],
#          [-0.91372549, -0.8745098 , -0.61568627]],
#
#         [[-0.78039216, -0.60784314, -0.24705882],
#          [-0.74117647, -0.6627451 , -0.20784314],
#          [-0.28627451, -0.22352941, -0.22352941],
#          ...,
#          [-0.95294118, -0.90588235, -0.5372549 ],
#          [-0.92156863, -0.79607843, -0.46666667],
#          [-0.92941176, -0.81176471, -0.41176471]],
#
#         [[-0.74901961, -0.55294118, -0.20784314],
#          [-0.56862745, -0.49019608, -0.33333333],
#          [ 0.01176471,  0.00392157, -0.11372549],
#          ...,
#          [-0.89019608, -0.62352941,  0.35686275],
#          [-0.78823529, -0.52941176,  0.17647059],
#          [-1.        , -0.8745098 , -0.33333333]],
#
#         ...,
#
#         [[ 0.5372549 ,  0.28627451,  0.21568627],
#          [ 0.5372549 ,  0.16078431,  0.12941176],
#          [ 0.50588235,  0.23137255,  0.36470588],
#          ...,
#          [ 0.40392157,  0.42745098,  0.25490196],
#          [ 0.42745098,  0.45098039,  0.29411765],
#          [ 0.25490196,  0.28627451,  0.10588235]],
#
#         [[ 0.45882353,  0.1372549 ,  0.16862745],
#          [ 0.57647059,  0.24705882,  0.23921569],
#          [ 0.56862745,  0.22352941,  0.23137255],
#          ...,
#          [ 0.37254902,  0.40392157,  0.19215686],
#          [ 0.41176471,  0.42745098,  0.25490196],
#          [ 0.37254902,  0.37254902,  0.23137255]],
#
#         [[ 0.46666667,  0.11372549,  0.17647059],
#          [ 0.52941176,  0.20784314,  0.23921569],
#          [ 0.55294118,  0.33333333,  0.29411765],
#          ...,
#          [ 0.45098039,  0.44313725,  0.23921569],
#          [ 0.46666667,  0.44313725,  0.24705882],
#          [ 0.49803922,  0.44313725,  0.25490196]]],
#
#
#        ...,
#
#
#        [[[ 0.49803922,  0.35686275,  0.33333333],
#          [ 0.52156863,  0.38823529,  0.38823529],
#          [ 0.48235294,  0.40392157,  0.43529412],
#          ...,
#          [ 0.18431373, -0.05098039, -0.34117647],
#          [ 0.00392157, -0.1372549 , -0.33333333],
#          [ 0.0745098 , -0.06666667, -0.25490196]],
#
#         [[ 0.30196078,  0.27843137,  0.37254902],
#          [ 0.29411765,  0.31764706,  0.40392157],
#          [ 0.27058824,  0.3254902 ,  0.42745098],
#          ...,
#          [ 0.39607843,  0.1372549 , -0.19215686],
#          [ 0.44313725,  0.16078431, -0.19215686],
#          [ 0.41176471,  0.11372549, -0.23921569]],
#
#         [[ 0.15294118,  0.15294118,  0.15294118],
#          [ 0.34901961,  0.38823529,  0.45098039],
#          [ 0.39607843,  0.42745098,  0.49803922],
#          ...,
#          [ 0.60784314,  0.46666667,  0.29411765],
#          [ 0.58431373,  0.43529412,  0.25490196],
#          [ 0.42745098,  0.17647059, -0.12156863]],
#
#         ...,
#
#         [[ 0.30980392,  0.05882353, -0.28627451],
#          [ 0.24705882,  0.0745098 , -0.21568627],
#          [ 0.2627451 ,  0.16078431, -0.16862745],
#          ...,
#          [ 0.37254902,  0.30196078,  0.25490196],
#          [ 0.38039216,  0.12156863, -0.19215686],
#          [ 0.3254902 ,  0.09803922, -0.19215686]],
#
#         [[ 0.22352941, -0.01960784, -0.36470588],
#          [ 0.3254902 ,  0.09803922, -0.2       ],
#          [ 0.39607843,  0.30196078,  0.10588235],
#          ...,
#          [ 0.38823529,  0.29411765,  0.19215686],
#          [ 0.31764706,  0.03529412, -0.3254902 ],
#          [ 0.23921569, -0.00392157, -0.30980392]],
#
#         [[ 0.12156863, -0.08235294, -0.39607843],
#          [ 0.31764706,  0.0745098 , -0.23921569],
#          [ 0.49019608,  0.41176471,  0.36470588],
#          ...,
#          [ 0.25490196,  0.03529412, -0.2627451 ],
#          [ 0.16862745, -0.04313725, -0.33333333],
#          [ 0.16078431, -0.04313725, -0.33333333]]],
#
#
#        [[[-0.38823529, -0.38039216, -0.6       ],
#          [-0.50588235, -0.49019608, -0.70196078],
#          [-0.43529412, -0.42745098, -0.62352941],
#          ...,
#          [-0.41176471, -0.49019608, -0.70980392],
#          [-0.78823529, -0.81960784, -0.88235294],
#          [-0.92156863, -0.92941176, -0.92156863]],
#
#         [[-0.31764706, -0.33333333, -0.61568627],
#          [ 0.31764706,  0.31764706, -0.04313725],
#          [ 0.09019608,  0.2       , -0.2627451 ],
#          ...,
#          [ 0.85882353,  0.63137255,  0.05098039],
#          [-0.06666667, -0.14509804, -0.43529412],
#          [-0.99215686, -0.99215686, -0.97647059]],
#
#         [[-0.03529412, -0.05882353, -0.42745098],
#          [ 0.77254902,  0.86666667,  0.20784314],
#          [ 0.30980392,  0.56078431, -0.2       ],
#          ...,
#          [ 0.83529412,  0.54509804, -0.08235294],
#          [ 0.15294118,  0.05882353, -0.31764706],
#          [-0.99215686, -1.        , -0.97647059]],
#
#         ...,
#
#         [[ 0.25490196,  0.25490196, -0.0745098 ],
#          [ 0.16078431,  0.09019608, -0.23137255],
#          [-0.44313725, -0.49803922, -0.69411765],
#          ...,
#          [-0.10588235, -0.2       , -0.41176471],
#          [ 0.12156863,  0.04313725, -0.20784314],
#          [-0.81176471, -0.84313725, -0.86666667]],
#
#         [[ 0.01960784,  0.02745098, -0.2627451 ],
#          [ 0.35686275,  0.28627451, -0.08235294],
#          [ 0.42745098,  0.39607843,  0.0745098 ],
#          ...,
#          [-0.48235294, -0.51372549, -0.65490196],
#          [-0.76470588, -0.78823529, -0.83529412],
#          [-0.9372549 , -0.9372549 , -0.9372549 ]],
#
#         [[-0.01960784, -0.00392157, -0.23921569],
#          [-0.23137255, -0.29411765, -0.58431373],
#          [-0.52941176, -0.56862745, -0.79607843],
#          ...,
#          [-0.55294118, -0.6       , -0.70980392],
#          [-0.92156863, -0.9372549 , -0.96078431],
#          [-0.91372549, -0.92156863, -0.90588235]]],
#
#
#        [[[ 0.28627451, -0.06666667, -0.36470588],
#          [ 0.21568627, -0.09803922, -0.37254902],
#          [ 0.30980392, -0.0745098 , -0.36470588],
#          ...,
#          [ 0.00392157,  0.09019608,  0.10588235],
#          [-0.01960784,  0.06666667,  0.09019608],
#          [-0.0745098 ,  0.03529412,  0.08235294]],
#
#         [[ 0.52941176,  0.10588235, -0.23137255],
#          [ 0.39607843,  0.01960784, -0.28627451],
#          [ 0.42745098,  0.01176471, -0.30980392],
#          ...,
#          [ 0.05098039,  0.12941176,  0.1372549 ],
#          [ 0.04313725,  0.12941176,  0.1372549 ],
#          [-0.05882353,  0.05098039,  0.10588235]],
#
#         [[ 0.37254902, -0.01960784, -0.34117647],
#          [ 0.41176471,  0.00392157, -0.3254902 ],
#          [ 0.38039216, -0.00392157, -0.3254902 ],
#          ...,
#          [ 0.00392157,  0.09019608,  0.10588235],
#          [-0.02745098,  0.06666667,  0.09019608],
#          [-0.04313725,  0.05882353,  0.09803922]],
#
#         ...,
#
#         [[-0.35686275, -0.43529412, -0.49019608],
#          [-0.2627451 , -0.34901961, -0.45098039],
#          [-0.28627451, -0.36470588, -0.45098039],
#          ...,
#          [-0.48235294, -0.56862745, -0.62352941],
#          [ 0.16078431, -0.00392157, -0.25490196],
#          [ 0.3254902 ,  0.17647059, -0.09019608]],
#
#         [[-0.37254902, -0.44313725, -0.50588235],
#          [-0.2627451 , -0.36470588, -0.46666667],
#          [-0.27058824, -0.37254902, -0.45882353],
#          ...,
#          [-0.36470588, -0.46666667, -0.55294118],
#          [ 0.14509804, -0.00392157, -0.23137255],
#          [ 0.27058824,  0.12156863, -0.1372549 ]],
#
#         [[-0.30980392, -0.38823529, -0.4745098 ],
#          [-0.28627451, -0.38039216, -0.49019608],
#          [-0.25490196, -0.34901961, -0.45098039],
#          ...,
#          [-0.17647059, -0.30196078, -0.44313725],
#          [ 0.25490196,  0.08235294, -0.19215686],
#          [ 0.19215686,  0.05098039, -0.2       ]]]])
